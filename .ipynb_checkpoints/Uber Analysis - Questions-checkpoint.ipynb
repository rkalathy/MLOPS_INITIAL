# %% [markdown]
# ### Assignment  - Uber Data Analysis
#
# The dataset contains the uber trips details for year 2016.
# Lets explore the dataset
#
# #### Dataset -
# The dataset contains Start Date, End Date, Start Location, End Location, Miles Driven and Purpose of drive (Business, Personal, Meals, Errands, Meetings, Customer Support etc.)

# %% [markdown]
# #### Steps to Solve the Assignment:
#
# 1.Import the libraries
#
# 2.Load the data
#
# 3.Answer the questions

# %%
#Import the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Read the data from csv , file name : uberdrive.csv

# %%
df = pd.read_csv("uber.csv")
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# 2. Display first 20 rows of data

# %%
df.head(20)
# Out:
#         START_DATE*        END_DATE* CATEGORY*             START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business        Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business        Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business        Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business        Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business        Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business    West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business    West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business               Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business               Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business            Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business           New York
# 11  1/10/2016 18:18  1/10/2016 18:53  Business           Elmhurst
# 12  1/10/2016 19:12  1/10/2016 19:32  Business            Midtown
# ...

# %% [markdown]
# 3. Display last 10 rows from the data

# %%
df.tail(10)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Kar?chi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Kar?chi      2.9  Errand/Supplies
# 1147           Kar?chi      4.6  Errand/Supplies
# 1148           Kar?chi      4.6          Meeting
# ...

# %% [markdown]
# 4. Access the shape and Size attribute of the dataframe

# %%
print("Shape of DataFrame:", df.shape)  # (rows, columns)
print("Size of DataFrame:", df.size)    # total number of elements (rows * columns)
# Out:
# Shape of DataFrame: (1156, 7)
# Size of DataFrame: 8092

# %% [markdown]
# 5. call info method on the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# 6. Check for total number of null/missing rows in the dataframe

# %%
missing_rows = df.isnull().any(axis=1).sum()
print("Total number of rows with missing values:", missing_rows)
# Out:
# Total number of rows with missing values: 503

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %% [markdown]
# 7. Return the Rows where the value of PURPOSE column is null

# %%
# Check actual column names
print(df.columns)  # To confirm exact spelling of 'PURPOSE'

# Now filter rows where the PURPOSE column is null
null_purpose_rows = df[df["PURPOSE*"].isnull()]
print(null_purpose_rows)
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
# ...

# %%
df[df["PURPOSE*"].isnull()]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85      2/9/2016 10:54    2/9/2016 11:07  Personal       Whitebridge
# 86      2/9/2016 11:43    2/9/2016 11:50  Personal        Northwoods
# 87      2/9/2016 13:36    2/9/2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                     STOP*   MILES* PURPOSE*
# 1             Fort Pierce      5.0      NaN
# 32    Lake Wellingborough      7.2      NaN
# ...

# %% [markdown]
# 8. Return the Dataframe where the value in Miles Column is greater than 50

# %%
print(df.columns)  # To confirm exact spelling of 'PURPOSE'

miles_over_50 = df[df["MILES*"] > 50]

print(miles_over_50)
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 232    3/17/2016 12:52   3/17/2016 15:11  Business            Austin
# 251    3/19/2016 19:33   3/19/2016 20:39  Business         Galveston
# 268    3/25/2016 13:24   3/25/2016 16:22  Business              Cary
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 295     4/2/2016 12:21    4/2/2016 14:47  Business         Kissimmee
# 296     4/2/2016 16:57    4/2/2016 18:09  Business     Daytona Beach
# 297     4/2/2016 19:38    4/2/2016 22:36  Business      Jacksonville
# 298     4/2/2016 23:11     4/3/2016 1:34  Business         Ridgeland
# 299      4/3/2016 2:00     4/3/2016 4:16  Business          Florence
# ...

# %%
df["MILES*"] > 50
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# 1155     True
# Name: MILES*, Length: 1156, dtype: bool

# %% [markdown]
# ##### Renaming the columns

# %%
df.columns
# Out:
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("*","")
df.columns
# Out:
# /var/folders/cx/fhw6mg3931x0bmvqvdc89qb80000gn/T/ipykernel_39804/4240322960.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.replace("*","")
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %% [markdown]
# 9. Sort the values of the data frame by the column of : MILES in an Ascending Order

# %%
df.sort_values(by="MILES", ascending=True)
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 1111   12/25/2016 0:10   12/25/2016 0:14  Business            Lahore
# 1110  12/24/2016 22:04  12/24/2016 22:09  Business            Lahore
# ...                ...               ...       ...               ...
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 420            Tribeca      0.5  Errand/Supplies
# ...

# %% [markdown]
# 10. Return the minimum value present in column of MILES

# %%
df['MILES'].min()
# Out:
# 0.5

# %% [markdown]
# 11. Return the maximum value present in column of MILES

# %%
df['MILES'].max()
# Out:
# 12204.7

# %% [markdown]
# 12. Remove the last row from the dataframe & store in a new dataframe as : df2

# %%
df2 = df.iloc[:-1]

# %% [markdown]
# 13. Call Describe method on a dataframe

# %%
df2.describe()
# Out:
#              MILES
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# 14. Drop null values from the dataframe ? Hint: use `dropna()` method & store in a new data frame df3

# %%
df3 = df.dropna()

# %%
df3
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %% [markdown]
# 15. Get the list of Unique Start points. (from original df dataframe)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# 16. What is the Total Number of Unique Start Points ?

# %%
df['START'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
# ...

# %%
df['START'].unique().tolist()
# Out:
# ['Fort Pierce',
#  'West Palm Beach',
#  'Cary',
#  'Jamaica',
#  'New York',
#  'Elmhurst',
#  'Midtown',
#  'East Harlem',
#  'Flatiron District',
#  'Midtown East',
#  'Hudson Square',
#  'Lower Manhattan',
#  "Hell's Kitchen",
#  'Downtown',
#  'Gulfton',
#  'Houston',
#  'Eagan Park',
#  'Morrisville',
#  'Durham',
#  'Farmington Woods',
#  'Whitebridge',
#  'Lake Wellingborough',
#  'Fayetteville Street',
#  'Raleigh',
#  'Hazelwood',
#  'Fairmont',
#  'Meredith Townes',
#  'Apex',
#  'Chapel Hill',
#  'Northwoods',
#  'Edgehill Farms',
#  'Tanglewood',
#  'Preston',
#  'Eastgate',
#  'East Elmhurst',
#  'Jackson Heights',
#  'Long Island City',
#  'Katunayaka',
#  'Unknown Location',
#  'Colombo',
#  'Nugegoda',
#  'Islamabad',
#  'R?walpindi',
#  'Noorpur Shahan',
#  'Heritage Pines',
#  'Westpark Place',
#  'Waverly Place',
#  'Wayne Ridge',
#  'Weston',
#  'East Austin',
#  'West University',
#  'South Congress',
#  'The Drag',
#  'Congress Ave District',
# ...

# %%
len(df["START"].unique())
# Out:
# 178

# %% [markdown]
# 17. Get the list of Unique STOP points. (from Original df dataframe)

# %%
df['STOP'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Palm Beach', 'Cary',
#        'Morrisville', 'New York', 'Queens', 'East Harlem', 'NoMad',
#        'Midtown', 'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Queens County', 'Gulfton', 'Downtown',
#        'Houston', 'Jamestown Court', 'Durham', 'Whitebridge',
#        'Lake Wellingborough', 'Raleigh', 'Umstead', 'Hazelwood',
#        'Westpark Place', 'Meredith Townes', 'Leesville Hollow', 'Apex',
#        'Chapel Hill', 'Williamsburg Manor', 'Macgregor Downs',
#        'Edgehill Farms', 'Northwoods', 'Tanglewood', 'Preston',
#        'Walnut Terrace', 'Jackson Heights', 'East Elmhurst',
#        'Midtown West', 'Long Island City', 'Jamaica', 'Unknown Location',
#        'Colombo', 'Nugegoda', 'Katunayaka', 'Islamabad', 'R?walpindi',
#        'Noorpur Shahan', 'Heritage Pines', 'Waverly Place', 'Wayne Ridge',
#        'Depot Historic District', 'Weston', 'West University',
# ...

# %% [markdown]
# 18. What is the Total Number of Unique STOP Points ?

# %%
len(df['STOP'].unique())
# Out:
# 189

# %%
df['STOP'].unique().tolist()
# Out:
# ['Fort Pierce',
#  'West Palm Beach',
#  'Palm Beach',
#  'Cary',
#  'Morrisville',
#  'New York',
#  'Queens',
#  'East Harlem',
#  'NoMad',
#  'Midtown',
#  'Midtown East',
#  'Hudson Square',
#  'Lower Manhattan',
#  "Hell's Kitchen",
#  'Queens County',
#  'Gulfton',
#  'Downtown',
#  'Houston',
#  'Jamestown Court',
#  'Durham',
#  'Whitebridge',
#  'Lake Wellingborough',
#  'Raleigh',
#  'Umstead',
#  'Hazelwood',
#  'Westpark Place',
#  'Meredith Townes',
#  'Leesville Hollow',
#  'Apex',
#  'Chapel Hill',
#  'Williamsburg Manor',
#  'Macgregor Downs',
#  'Edgehill Farms',
#  'Northwoods',
#  'Tanglewood',
#  'Preston',
#  'Walnut Terrace',
#  'Jackson Heights',
#  'East Elmhurst',
#  'Midtown West',
#  'Long Island City',
#  'Jamaica',
#  'Unknown Location',
#  'Colombo',
#  'Nugegoda',
#  'Katunayaka',
#  'Islamabad',
#  'R?walpindi',
#  'Noorpur Shahan',
#  'Heritage Pines',
#  'Waverly Place',
#  'Wayne Ridge',
#  'Depot Historic District',
#  'Weston',
# ...

# %% [markdown]
# 19. Group the Dataframe by START points, and perform the aggregation of Sum of the column of MILES

# %%
df.groupby("START").sum()
# Out:
# /var/folders/cx/fhw6mg3931x0bmvqvdc89qb80000gn/T/ipykernel_39804/728539229.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("START").sum()
#                  MILES
# START
# Agnew             11.1
# Almond            15.2
# Apex              90.8
# Arabi             17.0
# Arlington          4.9
# ...                ...
# West University    4.4
# Weston             8.0
# Westpark Place    37.1
# Whitebridge      273.4
# Winston Salem    133.6
#
# [177 rows x 1 columns]

# %% [markdown]
# 20. Create a function that will help in parsing the column of START DATE & END DATE.
#
# Requirement:
#
# Function should take the value as: "1/1/2016 21:11" (Month, Date, Year , Hour, Minutes)
#
# Return as :  datetime.datetime(2016, 1, 1, 21, 11)  (Year Month Date Hour Minutes)
#
# (Refer to Exploratory Data Analysis section for help)

# %%
df.groupby('START')['MILES'].sum()
# Out:
# START
# Agnew               11.1
# Almond              15.2
# Apex                90.8
# Arabi               17.0
# Arlington            4.9
#                    ...
# West University      4.4
# Weston               8.0
# Westpark Place      37.1
# Whitebridge        273.4
# Winston Salem      133.6
# Name: MILES, Length: 177, dtype: float64

# %%
df_grouped = df.groupby('START', as_index=False)['MILES'].sum()
print(df_grouped)
# Out:
#                START  MILES
# 0              Agnew   11.1
# 1             Almond   15.2
# 2               Apex   90.8
# 3              Arabi   17.0
# 4          Arlington    4.9
# ..               ...    ...
# 172  West University    4.4
# 173           Weston    8.0
# 174   Westpark Place   37.1
# 175      Whitebridge  273.4
# 176    Winston Salem  133.6
#
# [177 rows x 2 columns]

# %% [markdown]
# 21. Apply Previously create date parser on the column of START DATE & END DATE with df2 (where the last row removed)

# %%
df3['START_DATE'] = pd.to_datetime(df2['START_DATE'])
df3['END_DATE'] = pd.to_datetime(df2['END_DATE'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'START_DATE'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# 22. Take the difference between END date and Start date to get the total journey time of the ride

# %%
df2['DURATION'] = df2['END DATE'] - df2['START DATE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'END DATE'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# 23. Return the row with Maximum journey time
